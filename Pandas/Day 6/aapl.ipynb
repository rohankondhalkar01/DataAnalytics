# %%
# Import pandas library for data manipulation and analysis
import pandas as pd
# Read the Apple stock data from CSV file, setting the 'Date' column as the index
df = pd.read_csv("/Users/rohankondhalkar/Desktop/Pandas/aapl.csv",index_col ="Date")
# Display the first 5 rows of the dataframe to preview the data
df.head()
# Out:
#              Open    High     Low   Close    Volume
# Date
# 7-Jul-17   142.90  144.75  142.90  144.18  19201712
# 6-Jul-17   143.02  143.50  142.41  142.73  24128782
# 5-Jul-17   143.69  144.79  142.72  144.09  21569557
# 3-Jul-17   144.88  145.30  143.10  143.50  14277848
# 30-Jun-17  144.45  144.96  143.78  144.02  23024107

# %%
type(df.Date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.index
# Out:
# Index(['7-Jul-17', '6-Jul-17', '5-Jul-17', '3-Jul-17', '30-Jun-17',
#        '29-Jun-17', '28-Jun-17', '27-Jun-17', '26-Jun-17', '23-Jun-17',
#        ...
#        '22-Jul-16', '21-Jul-16', '20-Jul-16', '19-Jul-16', '18-Jul-16',
#        '15-Jul-16', '14-Jul-16', '13-Jul-16', '12-Jul-16', '11-Jul-16'],
#       dtype='object', name='Date', length=251)

# %%
df.Close
# Out:
# Date
# 7-Jul-17     144.18
# 6-Jul-17     142.73
# 5-Jul-17     144.09
# 3-Jul-17     143.50
# 30-Jun-17    144.02
#               ...
# 15-Jul-16     98.78
# 14-Jul-16     98.79
# 13-Jul-16     96.87
# 12-Jul-16     97.42
# 11-Jul-16     96.98
# Name: Close, Length: 251, dtype: float64

# %%
df.index = pd.to_datetime(df.index)
type(df.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
df['Close'].resample('W').mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df.Volume.plot(kind = 'barh')
# Out:
# <Axes: ylabel='Date'>
