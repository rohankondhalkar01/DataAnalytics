# %%
import pandas as pd
df = pd.read_csv("/Users/rohankondhalkar/Downloads/weather_data.csv")
df # Prints all the data element present in the csv file.
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.head() # Specific number which will retrive from the start of csv file.
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain

# %%
df.tail(2) # Specific number which will retrive from the end of csv file.
# Out:
#         day  temperature  windspeed  event
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df[1:5] # If you want to print specific numnber of data
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain

# %%
df['event'] # The String pass in the '' should be same as csv file name other wise it will throw error
# Out:
# 0     Rain
# 1    Sunny
# 2     Snow
# 3     Snow
# 4     Rain
# 5    Sunny
# Name: event, dtype: object

# %%
df['Events'] # It will throw error as no coloumn name as 'Event'.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Events'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df['Events']
#
# ...

# %%
type(df) # It will print the type of df which retrurns the lib and all details
# Out:
# pandas.core.frame.DataFrame

# %%
df[['event','day']] # We have pass the list to print the coln data
# Out:
#    event       day
# 0   Rain  1/1/2017
# 1  Sunny  1/2/2017
# 2   Snow  1/3/2017
# 3   Snow  1/4/2017
# 4   Rain  1/5/2017
# 5  Sunny  1/6/2017

# %%
df.temperature.max() # we can also use this for df['temperature'].max() max() is built in function
# Out:
# 35

# %%
df['temperature'].min()
# Out:
# 24

# %%
df.temperature.mean()
# Out:
# np.float64(30.333333333333332)

# %%
df.temperature.sum()
# Out:
# np.int64(182)

# %%
df.temperature.median()
# Out:
# 31.5

# %%
df.temperature.mode()
# Out:
# 0    32
# Name: temperature, dtype: int64

# %%
df.describe() # Here the describe activity is done on numerical value on order to find variuos values
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %%
df[df.temperature > 30] #To find out the specific condition we can do as following
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df[df.temperature ==  df.temperature.max()] #To find out the specific condition we can do as following
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny

# %%
df[['day','temperature']][df.temperature ==  df.temperature.max()] #To find out the specific condition we can do as following
# Out:
#         day  temperature
# 1  1/2/2017           35

# %%
df.reset_index(inplace = True) # reset the index to o to 6

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
# Set the 'day' column as the index of the dataframe
# The 'inplace=True' parameter modifies the dataframe directly instead of returning a new one
df.set_index('day', inplace = True)

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.loc[0] # Give the location of data
# Out:
# day            1/1/2017
# temperature          32
# windspeed             6
# event              Rain
# Name: 0, dtype: object
